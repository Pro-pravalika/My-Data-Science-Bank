# %% [markdown]
# ### seaborn Rug plots.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = sns.load_dataset('anagrams')
df
# Out:
#     subidr    attnr  num1  num2  num3
# 0        1  divided     2   4.0     7
# 1        2  divided     3   4.0     5
# 2        3  divided     3   5.0     6
# 3        4  divided     5   7.0     5
# 4        5  divided     4   5.0     8
# 5        6  divided     5   5.0     6
# 6        7  divided     5   4.5     6
# 7        8  divided     5   7.0     8
# 8        9  divided     2   3.0     7
# 9       10  divided     6   5.0     6
# 10      11  focused     6   5.0     6
# 11      12  focused     8   9.0     8
# 12      13  focused     6   5.0     9
# 13      14  focused     8   8.0     7
# 14      15  focused     8   8.0     7
# 15      16  focused     6   8.0     7
# 16      17  focused     7   7.0     6
# 17      18  focused     7   8.0     6
# 18      19  focused     5   6.0     6
# 19      20  focused     6   6.0     5

# %%
sns.rugplot(df['num2'])
# Out:
# <AxesSubplot:xlabel='num2'>

# %%
df = sns.load_dataset('gammas')
df
# Out:
#       timepoint  ROI  subject  BOLD signal
# 0           0.0  IPS        0     0.513433
# 1           0.0  IPS        1    -0.414368
# 2           0.0  IPS        2     0.214695
# 3           0.0  IPS        3     0.814809
# 4           0.0  IPS        4    -0.894992
# ...         ...  ...      ...          ...
# 5995       10.0   V1       15     0.068646
# 5996       10.0   V1       16     0.827451
# 5997       10.0   V1       17     1.363256
# 5998       10.0   V1       18     0.570810
# 5999       10.0   V1       19    -0.048178
#
# [6000 rows x 4 columns]

# %%
sns.rugplot(df['BOLD signal'])
# Out:
# <AxesSubplot:xlabel='BOLD signal'>
